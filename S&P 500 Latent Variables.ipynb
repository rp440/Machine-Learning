# %%
import pandas as pd
import datetime
#from google.colab import drive
# Read CSV file into DataFrame df
data = pd.read_csv('sp500_stocks.csv')
#drive.mount('/content/drive', force_remount=True)
#data = pd.read_csv("https://drive.google.com/file/d/1mEQo3VhYPNFbZCQyHDn4H98mhVH6meMS/view?usp=sharing", index_col = 0, error_bad_lines=False)
data.head()
# Show dataframe
df = (data.pipe(lambda x: x.assign(year = pd.to_datetime(x.Date).dt.year))[['Symbol', 'Date', 'year', 'Open', 'High','Close','Low','Adj Close','Volume']])
df.head()
# Out:
#   Symbol        Date  year       Open       High      Close        Low  \
# 0      A  2018-01-02  2018  67.419998  67.889999  67.599998  67.339996
# 1      A  2018-01-03  2018  67.620003  69.489998  69.320000  67.599998
# 2      A  2018-01-04  2018  69.540001  69.820000  68.800003  68.779999
# 3      A  2018-01-05  2018  68.730003  70.099998  69.900002  68.730003
# 4      A  2018-01-08  2018  69.730003  70.330002  70.050003  69.550003
#
#    Adj Close     Volume
# 0  65.305038  1047800.0
# 1  66.966644  1698900.0
# 2  66.464279  2230700.0
# 3  67.526955  1632500.0
# 4  67.671860  1613400.0

# %%
#first factor to be overall stock market movements
# !pip3 install yfinance
import bs4 as bs
import requests
import yfinance as yf
import datetime

spy_df = yf.download('SPY', start='2018-01-01', end='2022-08-31')
spy_df.to_csv('sp500.csv')
data2 = pd.read_csv('sp500.csv')
data2.head()
df2 = (data2.pipe(lambda x: x.assign(year = pd.to_datetime(x.Date).dt.year))[['Date', 'year', 'Open', 'High','Low','Close','Adj Close','Volume']])
#df2.rename(columns={'Date':'date','Open':'open','High':'high','Low':'low','Close':'close','Adj Close':'adj_close','Volume':'volume'},inplace = True)
df2.insert(0,'Symbol','SPY')
df2['overall_return'] = (df2['Close'].pct_change())*100
mean = df2['overall_return'].mean()
df2['overall_return'].fillna(value=mean, inplace=True)
df2.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#   Symbol        Date  year        Open        High         Low       Close  \
# 0    SPY  2018-01-02  2018  267.839996  268.809998  267.399994  268.769989
# 1    SPY  2018-01-03  2018  268.959991  270.640015  268.959991  270.470001
# 2    SPY  2018-01-04  2018  271.200012  272.160004  270.540009  271.609985
# 3    SPY  2018-01-05  2018  272.510010  273.559998  271.950012  273.420013
# 4    SPY  2018-01-08  2018  273.309998  274.100006  272.980011  273.920013
#
#     Adj Close    Volume  overall_return
# 0  247.899765  86655700        0.042635
# 1  249.467834  90070400        0.632516
# 2  250.519241  80636400        0.421483
# 3  252.188751  83524000        0.666407
# 4  252.649994  57319200        0.182869

# %%
#Beta calculation
import numpy as np
df['stock_market_return'] = (df['Close'].pct_change())*100
mean = df['stock_market_return'].mean()
df['stock_market_return'].fillna(value=mean, inplace=True)
df.head()

#beta = (covariance/variance)
# Out:
#   Symbol        Date  year       Open       High      Close        Low  \
# 0      A  2018-01-02  2018  67.419998  67.889999  67.599998  67.339996
# 1      A  2018-01-03  2018  67.620003  69.489998  69.320000  67.599998
# 2      A  2018-01-04  2018  69.540001  69.820000  68.800003  68.779999
# 3      A  2018-01-05  2018  68.730003  70.099998  69.900002  68.730003
# 4      A  2018-01-08  2018  69.730003  70.330002  70.050003  69.550003
#
#    Adj Close     Volume  stock_market_return
# 0  65.305038  1047800.0             0.094457
# 1  66.966644  1698900.0             2.544381
# 2  66.464279  2230700.0            -0.750139
# 3  67.526955  1632500.0             1.598835
# 4  67.671860  1613400.0             0.214594

# %%
merged_inner = pd.merge(left=df, right=df2, left_on='Date', right_on='Date')
merged_inner.head()
# Out:
#   Symbol_x        Date  year_x      Open_x      High_x     Close_x      Low_x  \
# 0        A  2018-01-02    2018   67.419998   67.889999   67.599998  67.339996
# 1      AAL  2018-01-02    2018   52.330002   53.099998   52.990002  51.900002
# 2      AAP  2018-01-02    2018  100.900002  107.930000  106.089996  99.709999
# 3     AAPL  2018-01-02    2018   42.540001   43.075001   43.064999  42.314999
# 4     ABBV  2018-01-02    2018   97.139999   98.900002   98.410004  96.750000
#
#    Adj Close_x     Volume_x  stock_market_return Symbol_y  year_y      Open_y  \
# 0    65.305038    1047800.0             0.094457      SPY    2018  267.839996
# 1    51.647560    4084700.0           -58.691922      SPY    2018  267.839996
# 2   100.788200    2624500.0           695.873946      SPY    2018  267.839996
# 3    41.018425  102223600.0           -74.737491      SPY    2018  267.839996
# 4    78.813736    4561300.0           -38.071864      SPY    2018  267.839996
#
#        High_y       Low_y     Close_y  Adj Close_y  Volume_y  overall_return
# 0  268.809998  267.399994  268.769989   247.899765  86655700        0.042635
# 1  268.809998  267.399994  268.769989   247.899765  86655700        0.042635
# 2  268.809998  267.399994  268.769989   247.899765  86655700        0.042635
# 3  268.809998  267.399994  268.769989   247.899765  86655700        0.042635
# 4  268.809998  267.399994  268.769989   247.899765  86655700        0.042635

# %%
merged_inner = merged_inner.drop(['Adj Close_y'], axis=1)
merged_inner.head()
# Out:
#   Symbol_x        Date  year_x      Open_x      High_x     Close_x      Low_x  \
# 0        A  2018-01-02    2018   67.419998   67.889999   67.599998  67.339996
# 1      AAL  2018-01-02    2018   52.330002   53.099998   52.990002  51.900002
# 2      AAP  2018-01-02    2018  100.900002  107.930000  106.089996  99.709999
# 3     AAPL  2018-01-02    2018   42.540001   43.075001   43.064999  42.314999
# 4     ABBV  2018-01-02    2018   97.139999   98.900002   98.410004  96.750000
#
#    Adj Close_x     Volume_x  stock_market_return Symbol_y  year_y      Open_y  \
# 0    65.305038    1047800.0             0.094457      SPY    2018  267.839996
# 1    51.647560    4084700.0           -58.691922      SPY    2018  267.839996
# 2   100.788200    2624500.0           695.873946      SPY    2018  267.839996
# 3    41.018425  102223600.0           -74.737491      SPY    2018  267.839996
# 4    78.813736    4561300.0           -38.071864      SPY    2018  267.839996
#
#        High_y       Low_y     Close_y  Volume_y  overall_return
# 0  268.809998  267.399994  268.769989  86655700        0.042635
# 1  268.809998  267.399994  268.769989  86655700        0.042635
# 2  268.809998  267.399994  268.769989  86655700        0.042635
# 3  268.809998  267.399994  268.769989  86655700        0.042635
# 4  268.809998  267.399994  268.769989  86655700        0.042635

# %%
#Beta = Covariance(Stock Returns, Market Returns) / Variance(Market Returns)
mean_a = merged_inner['overall_return'].mean()
mean_b = merged_inner['stock_market_return'].mean()
merged_inner['covariance'] = (merged_inner['overall_return']-mean_a)*(merged_inner['stock_market_return']-mean_b)
merged_inner.head()

merged_inner['Variance'] = merged_inner['overall_return'].var()
merged_inner.head()
merged_inner['beta'] = merged_inner['covariance']/merged_inner['Variance'] 
merged_inner.head()
merged_inner.drop(['Volume_y','Close_y','High_y','Low_y','Open_y','year_y','Symbol_y'] ,axis=1 , inplace=True)
merged_inner.head()
# Out:
#   Symbol_x        Date  year_x      Open_x      High_x     Close_x      Low_x  \
# 0        A  2018-01-02    2018   67.419998   67.889999   67.599998  67.339996
# 1      AAL  2018-01-02    2018   52.330002   53.099998   52.990002  51.900002
# 2      AAP  2018-01-02    2018  100.900002  107.930000  106.089996  99.709999
# 3     AAPL  2018-01-02    2018   42.540001   43.075001   43.064999  42.314999
# 4     ABBV  2018-01-02    2018   97.139999   98.900002   98.410004  96.750000
#
#    Adj Close_x     Volume_x  stock_market_return  overall_return  \
# 0    65.305038    1047800.0             0.094457        0.042635
# 1    51.647560    4084700.0           -58.691922        0.042635
# 2   100.788200    2624500.0           695.873946        0.042635
# 3    41.018425  102223600.0           -74.737491        0.042635
# 4    78.813736    4561300.0           -38.071864        0.042635
#
#      covariance  Variance          beta
# 0  1.703558e-19  1.811402  9.404636e-20
# 1  6.938729e-03  1.811402  3.830585e-03
# 2 -8.212490e-02  1.811402 -4.533776e-02
# 3  8.832635e-03  1.811402  4.876132e-03
# 4  4.504883e-03  1.811402  2.486959e-03

# %%
adf_df = merged_inner[['Symbol_x','Date','Close_x']]
adf_df.head()
# Out:
#   Symbol_x        Date     Close_x
# 0        A  2018-01-02   67.599998
# 1      AAL  2018-01-02   52.990002
# 2      AAP  2018-01-02  106.089996
# 3     AAPL  2018-01-02   43.064999
# 4     ABBV  2018-01-02   98.410004

# %%
data = pd.read_csv('csv_data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1174 entries, 0 to 1173
# Columns: 502 entries, Date to ZTS
# dtypes: float64(501), object(1)
# memory usage: 4.5+ MB

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.columns[data.isnull().any()]
# Out:
# Index(['CARR', 'CDAY', 'CEG', 'CTVA', 'DOW', 'FOX', 'FOXA', 'MRNA', 'OGN',
#        'OTIS'],
#       dtype='object')

# %%
data
# Out:
#             Date           A        AAL         AAP        AAPL        ABBV  \
# 0     02-01-2018   67.599998  52.990002  106.089996   43.064999   98.410004
# 1     03-01-2018   69.320000  52.340000  107.050003   43.057499   99.949997
# 2     04-01-2018   68.800003  52.669998  111.000000   43.257500   99.379997
# 3     05-01-2018   69.900002  52.650002  112.180000   43.750000  101.110001
# 4     08-01-2018   70.050003  52.130001  111.389999   43.587502   99.489998
# ...          ...         ...        ...         ...         ...         ...
# 1169  24-08-2022  133.669998  13.990000  179.910004  167.529999  137.910004
# 1170  25-08-2022  136.009995  14.420000  180.990005  170.029999  139.330002
# 1171  26-08-2022  129.869995  13.740000  173.589996  163.619995  136.350006
# 1172  29-08-2022  128.110001  13.510000  170.539993  161.380005  135.710007
# 1173  30-08-2022  128.279999  13.330000  170.470001  158.910004  135.550003
#
#              ABC        ABMD         ABT         ACN  ...        WYNN  \
# 0      94.040001  192.490005   58.790001  153.839996  ...  164.300003
# 1      94.389999  195.820007   58.919998  154.550003  ...  162.520004
# 2      94.180000  199.250000   58.820000  156.380005  ...  163.399994
# 3      95.320000  202.320007   58.990002  157.669998  ...  164.490005
# 4      96.900002  207.800003   58.820000  158.929993  ...  162.300003
# ...          ...         ...         ...         ...  ...         ...
# 1169  148.229996  268.040008  105.440002  306.260010  ...   62.820000
# 1170  150.419998  274.450012  105.889999  309.769989  ...   64.949997
# 1171  146.190002  258.119995  101.900002  298.130005  ...   62.330002
# 1172  147.490005  256.980011  101.839996  295.140015  ...   62.410000
# 1173  145.429993  258.649994  102.199997  292.500000  ...   60.209999
#
#             XEL         XOM       XRAY        XYL         YUM         ZBH  \
# 0     47.810001   85.029999  67.139999  68.070000   81.599998  120.446602
# 1     47.490002   86.699997  66.910004  68.900002   81.529999  121.281555
# 2     47.119999   86.820000  66.900002  69.360001   82.360001  121.106796
# 3     46.790001   86.750000  67.839996  69.230003   82.839996  122.310677
# 4     47.139999   87.139999  68.300003  69.480003   82.980003  122.543686
# ...         ...         ...        ...        ...         ...         ...
# 1169  75.410004   98.580002  34.360001  96.129997  114.669998  109.699997
# 1170  76.080002   99.089996  34.759998  97.550003  116.820000  111.940002
# 1171  74.930000   97.870003  33.610001  92.970001  112.160004  107.510002
# 1172  75.620003  100.120003  33.080002  92.050003  112.209999  107.620003
# 1173  74.690002   96.309998  32.939999  91.349998  110.779999  107.370003
#
#             ZBRA       ZION         ZTS
# 0     103.709999  50.700001   71.769997
# 1     105.769997  50.639999   72.099998
# 2     107.860001  50.849998   72.529999
# 3     109.540001  50.869999   73.360001
# 4     110.629997  50.619999   74.239998
# ...          ...        ...         ...
# 1169  319.339996  56.279999  162.630005
# 1170  330.140015  57.310001  165.529999
# 1171  308.160004  56.439999  159.889999
# 1172  307.899994  55.750000  157.869995
# 1173  302.859985  55.400002  157.080002
#
# [1174 rows x 502 columns]

# %%
data.drop(['CARR', 'CDAY', 'CEG', 'CTVA', 'DOW', 'FOX', 'FOXA', 'MRNA', 'OGN','OTIS'],axis=1, inplace=True)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.set_index('Date', inplace=True)
data
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# Date
# 02-01-2018   67.599998  52.990002  106.089996   43.064999   98.410004
# 03-01-2018   69.320000  52.340000  107.050003   43.057499   99.949997
# 04-01-2018   68.800003  52.669998  111.000000   43.257500   99.379997
# 05-01-2018   69.900002  52.650002  112.180000   43.750000  101.110001
# 08-01-2018   70.050003  52.130001  111.389999   43.587502   99.489998
# ...                ...        ...         ...         ...         ...
# 24-08-2022  133.669998  13.990000  179.910004  167.529999  137.910004
# 25-08-2022  136.009995  14.420000  180.990005  170.029999  139.330002
# 26-08-2022  129.869995  13.740000  173.589996  163.619995  136.350006
# 29-08-2022  128.110001  13.510000  170.539993  161.380005  135.710007
# 30-08-2022  128.279999  13.330000  170.470001  158.910004  135.550003
#
#                    ABC        ABMD         ABT         ACN        ADBE  ...  \
# Date                                                                    ...
# 02-01-2018   94.040001  192.490005   58.790001  153.839996  177.699997  ...
# 03-01-2018   94.389999  195.820007   58.919998  154.550003  181.039993  ...
# 04-01-2018   94.180000  199.250000   58.820000  156.380005  183.220001  ...
# 05-01-2018   95.320000  202.320007   58.990002  157.669998  185.339996  ...
# 08-01-2018   96.900002  207.800003   58.820000  158.929993  185.039993  ...
# ...                ...         ...         ...         ...         ...  ...
# 24-08-2022  148.229996  268.040008  105.440002  306.260010  405.649994  ...
# 25-08-2022  150.419998  274.450012  105.889999  309.769989  403.929993  ...
# 26-08-2022  146.190002  258.119995  101.900002  298.130005  381.019989  ...
# 29-08-2022  147.490005  256.980011  101.839996  295.140015  375.260010  ...
# 30-08-2022  145.429993  258.649994  102.199997  292.500000  375.070007  ...
#
#                   WYNN        XEL         XOM       XRAY        XYL  \
# Date
# 02-01-2018  164.300003  47.810001   85.029999  67.139999  68.070000
# 03-01-2018  162.520004  47.490002   86.699997  66.910004  68.900002
# 04-01-2018  163.399994  47.119999   86.820000  66.900002  69.360001
# 05-01-2018  164.490005  46.790001   86.750000  67.839996  69.230003
# 08-01-2018  162.300003  47.139999   87.139999  68.300003  69.480003
# ...                ...        ...         ...        ...        ...
# 24-08-2022   62.820000  75.410004   98.580002  34.360001  96.129997
# 25-08-2022   64.949997  76.080002   99.089996  34.759998  97.550003
# 26-08-2022   62.330002  74.930000   97.870003  33.610001  92.970001
# 29-08-2022   62.410000  75.620003  100.120003  33.080002  92.050003
# 30-08-2022   60.209999  74.690002   96.309998  32.939999  91.349998
#
#                    YUM         ZBH        ZBRA       ZION         ZTS
# Date
# 02-01-2018   81.599998  120.446602  103.709999  50.700001   71.769997
# 03-01-2018   81.529999  121.281555  105.769997  50.639999   72.099998
# 04-01-2018   82.360001  121.106796  107.860001  50.849998   72.529999
# 05-01-2018   82.839996  122.310677  109.540001  50.869999   73.360001
# 08-01-2018   82.980003  122.543686  110.629997  50.619999   74.239998
# ...                ...         ...         ...        ...         ...
# 24-08-2022  114.669998  109.699997  319.339996  56.279999  162.630005
# 25-08-2022  116.820000  111.940002  330.140015  57.310001  165.529999
# 26-08-2022  112.160004  107.510002  308.160004  56.439999  159.889999
# 29-08-2022  112.209999  107.620003  307.899994  55.750000  157.869995
# 30-08-2022  110.779999  107.370003  302.859985  55.400002  157.080002
#
# [1174 rows x 491 columns]

# %%
from statsmodels.tsa.stattools import adfuller

def adf_statistics(time_series):
    """
    Augmented Dickey-Fuller test for stationarity
    """
    result = adfuller(time_series)
    if result[1] < 0.0500:             # result[1] contains the p-value
        return 0                       # returns 0 value if p-value of test is under 5%
    else:
        return 1

# %%
def adf_tests(df):
    """
    Augmented Dickey-Fuller test applied to every column in DataFrame
results = df.apply(adf_statistics, axis=0) # Output is a Pandas series
    """
    results = df.apply(adf_statistics) # Output is a Pandas series
    if sum(results)==0:
        print('Null hypothesis of non-stationarity is rejected for ALL series with p-values < 5%')
    else:
        for i, v in results.items():
            if v == 1:
                print(f'Null hypothesis of non-stationarity of {i} series is NOT rejected')
            else:
                print(f'Null hypothesis of non-stationarity of {i} series is rejected')

# %%
adf_tests(data)
# Out:
# Null hypothesis of non-stationarity of A series is NOT rejected
# Null hypothesis of non-stationarity of AAL series is NOT rejected
# Null hypothesis of non-stationarity of AAP series is NOT rejected
# Null hypothesis of non-stationarity of AAPL series is NOT rejected
# Null hypothesis of non-stationarity of ABBV series is NOT rejected
# Null hypothesis of non-stationarity of ABC series is NOT rejected
# Null hypothesis of non-stationarity of ABMD series is NOT rejected
# Null hypothesis of non-stationarity of ABT series is NOT rejected
# Null hypothesis of non-stationarity of ACN series is NOT rejected
# Null hypothesis of non-stationarity of ADBE series is NOT rejected
# Null hypothesis of non-stationarity of ADI series is NOT rejected
# Null hypothesis of non-stationarity of ADM series is NOT rejected
# Null hypothesis of non-stationarity of ADP series is NOT rejected
# Null hypothesis of non-stationarity of ADSK series is NOT rejected
# Null hypothesis of non-stationarity of AEE series is NOT rejected
# Null hypothesis of non-stationarity of AEP series is NOT rejected
# Null hypothesis of non-stationarity of AES series is NOT rejected
# Null hypothesis of non-stationarity of AFL series is NOT rejected
# Null hypothesis of non-stationarity of AIG series is NOT rejected
# Null hypothesis of non-stationarity of AIZ series is NOT rejected
# Null hypothesis of non-stationarity of AJG series is NOT rejected
# Null hypothesis of non-stationarity of AKAM series is NOT rejected
# Null hypothesis of non-stationarity of ALB series is NOT rejected
# Null hypothesis of non-stationarity of ALGN series is NOT rejected
# Null hypothesis of non-stationarity of ALK series is NOT rejected
# Null hypothesis of non-stationarity of ALL series is NOT rejected
# Null hypothesis of non-stationarity of ALLE series is NOT rejected
# Null hypothesis of non-stationarity of AMAT series is NOT rejected
# Null hypothesis of non-stationarity of AMCR series is NOT rejected
# Null hypothesis of non-stationarity of AMD series is NOT rejected
# Null hypothesis of non-stationarity of AME series is NOT rejected
# Null hypothesis of non-stationarity of AMGN series is NOT rejected
# Null hypothesis of non-stationarity of AMP series is NOT rejected
# Null hypothesis of non-stationarity of AMT series is NOT rejected
# Null hypothesis of non-stationarity of AMZN series is NOT rejected
# Null hypothesis of non-stationarity of ANET series is NOT rejected
# Null hypothesis of non-stationarity of ANSS series is NOT rejected
# Null hypothesis of non-stationarity of AON series is NOT rejected
# Null hypothesis of non-stationarity of AOS series is NOT rejected
# Null hypothesis of non-stationarity of APA series is NOT rejected
# Null hypothesis of non-stationarity of APD series is NOT rejected
# Null hypothesis of non-stationarity of APH series is NOT rejected
# Null hypothesis of non-stationarity of APTV series is NOT rejected
# Null hypothesis of non-stationarity of ARE series is NOT rejected
# Null hypothesis of non-stationarity of ATO series is NOT rejected
# Null hypothesis of non-stationarity of ATVI series is NOT rejected
# Null hypothesis of non-stationarity of AVB series is NOT rejected
# Null hypothesis of non-stationarity of AVGO series is NOT rejected
# Null hypothesis of non-stationarity of AVY series is NOT rejected
# Null hypothesis of non-stationarity of AWK series is NOT rejected
# Null hypothesis of non-stationarity of AXP series is NOT rejected
# Null hypothesis of non-stationarity of AZO series is NOT rejected
# Null hypothesis of non-stationarity of BA series is NOT rejected
# Null hypothesis of non-stationarity of BAC series is NOT rejected
# Null hypothesis of non-stationarity of BALL series is NOT rejected
# Null hypothesis of non-stationarity of BAX series is NOT rejected
# Null hypothesis of non-stationarity of BBWI series is NOT rejected
# Null hypothesis of non-stationarity of BBY series is NOT rejected
# Null hypothesis of non-stationarity of BDX series is rejected
# Null hypothesis of non-stationarity of BEN series is rejected
# Null hypothesis of non-stationarity of BIIB series is NOT rejected
# Null hypothesis of non-stationarity of BIO series is NOT rejected
# Null hypothesis of non-stationarity of BK series is NOT rejected
# Null hypothesis of non-stationarity of BKNG series is NOT rejected
# Null hypothesis of non-stationarity of BKR series is NOT rejected
# Null hypothesis of non-stationarity of BLK series is NOT rejected
# Null hypothesis of non-stationarity of BMY series is NOT rejected
# Null hypothesis of non-stationarity of BR series is NOT rejected
# Null hypothesis of non-stationarity of BRO series is NOT rejected
# Null hypothesis of non-stationarity of BSX series is NOT rejected
# Null hypothesis of non-stationarity of BWA series is NOT rejected
# Null hypothesis of non-stationarity of BXP series is NOT rejected
# Null hypothesis of non-stationarity of C series is NOT rejected
# Null hypothesis of non-stationarity of CAG series is NOT rejected
# Null hypothesis of non-stationarity of CAH series is rejected
# Null hypothesis of non-stationarity of CAT series is NOT rejected
# Null hypothesis of non-stationarity of CB series is NOT rejected
# Null hypothesis of non-stationarity of CBOE series is NOT rejected
# Null hypothesis of non-stationarity of CBRE series is NOT rejected
# Null hypothesis of non-stationarity of CCI series is NOT rejected
# Null hypothesis of non-stationarity of CCL series is NOT rejected
# Null hypothesis of non-stationarity of CDNS series is NOT rejected
# Null hypothesis of non-stationarity of CDW series is NOT rejected
# Null hypothesis of non-stationarity of CE series is NOT rejected
# Null hypothesis of non-stationarity of CF series is NOT rejected
# Null hypothesis of non-stationarity of CFG series is NOT rejected
# Null hypothesis of non-stationarity of CHD series is NOT rejected
# Null hypothesis of non-stationarity of CHRW series is NOT rejected
# Null hypothesis of non-stationarity of CHTR series is NOT rejected
# Null hypothesis of non-stationarity of CI series is NOT rejected
# Null hypothesis of non-stationarity of CINF series is NOT rejected
# Null hypothesis of non-stationarity of CL series is NOT rejected
# Null hypothesis of non-stationarity of CLX series is NOT rejected
# Null hypothesis of non-stationarity of CMA series is NOT rejected
# Null hypothesis of non-stationarity of CMCSA series is NOT rejected
# Null hypothesis of non-stationarity of CME series is NOT rejected
# Null hypothesis of non-stationarity of CMG series is NOT rejected
# Null hypothesis of non-stationarity of CMI series is NOT rejected
# Null hypothesis of non-stationarity of CMS series is NOT rejected
# Null hypothesis of non-stationarity of CNC series is NOT rejected
# Null hypothesis of non-stationarity of CNP series is NOT rejected
# Null hypothesis of non-stationarity of COF series is NOT rejected
# Null hypothesis of non-stationarity of COO series is NOT rejected
# Null hypothesis of non-stationarity of COP series is NOT rejected
# Null hypothesis of non-stationarity of COST series is NOT rejected
# Null hypothesis of non-stationarity of CPB series is NOT rejected
# Null hypothesis of non-stationarity of CPRT series is NOT rejected
# Null hypothesis of non-stationarity of CPT series is NOT rejected
# Null hypothesis of non-stationarity of CRL series is NOT rejected
# Null hypothesis of non-stationarity of CRM series is NOT rejected
# Null hypothesis of non-stationarity of CSCO series is NOT rejected
# Null hypothesis of non-stationarity of CSGP series is NOT rejected
# Null hypothesis of non-stationarity of CSX series is NOT rejected
# Null hypothesis of non-stationarity of CTAS series is NOT rejected
# Null hypothesis of non-stationarity of CTLT series is NOT rejected
# Null hypothesis of non-stationarity of CTRA series is NOT rejected
# Null hypothesis of non-stationarity of CTSH series is NOT rejected
# Null hypothesis of non-stationarity of CTXS series is NOT rejected
# Null hypothesis of non-stationarity of CVS series is NOT rejected
# Null hypothesis of non-stationarity of CVX series is NOT rejected
# Null hypothesis of non-stationarity of CZR series is NOT rejected
# Null hypothesis of non-stationarity of D series is NOT rejected
# Null hypothesis of non-stationarity of DAL series is NOT rejected
# Null hypothesis of non-stationarity of DD series is NOT rejected
# Null hypothesis of non-stationarity of DE series is NOT rejected
# Null hypothesis of non-stationarity of DFS series is NOT rejected
# Null hypothesis of non-stationarity of DG series is NOT rejected
# Null hypothesis of non-stationarity of DGX series is NOT rejected
# Null hypothesis of non-stationarity of DHI series is NOT rejected
# Null hypothesis of non-stationarity of DHR series is NOT rejected
# Null hypothesis of non-stationarity of DIS series is NOT rejected
# Null hypothesis of non-stationarity of DISH series is NOT rejected
# Null hypothesis of non-stationarity of DLR series is NOT rejected
# Null hypothesis of non-stationarity of DLTR series is NOT rejected
# Null hypothesis of non-stationarity of DOV series is NOT rejected
# Null hypothesis of non-stationarity of DPZ series is NOT rejected
# Null hypothesis of non-stationarity of DRE series is NOT rejected
# Null hypothesis of non-stationarity of DRI series is NOT rejected
# Null hypothesis of non-stationarity of DTE series is NOT rejected
# Null hypothesis of non-stationarity of DUK series is NOT rejected
# Null hypothesis of non-stationarity of DVA series is NOT rejected
# Null hypothesis of non-stationarity of DVN series is NOT rejected
# Null hypothesis of non-stationarity of DXC series is NOT rejected
# Null hypothesis of non-stationarity of DXCM series is NOT rejected
# Null hypothesis of non-stationarity of EA series is NOT rejected
# Null hypothesis of non-stationarity of EBAY series is NOT rejected
# Null hypothesis of non-stationarity of ECL series is NOT rejected
# Null hypothesis of non-stationarity of ED series is NOT rejected
# Null hypothesis of non-stationarity of EFX series is NOT rejected
# Null hypothesis of non-stationarity of EIX series is rejected
# Null hypothesis of non-stationarity of EL series is NOT rejected
# Null hypothesis of non-stationarity of ELV series is NOT rejected
# Null hypothesis of non-stationarity of EMN series is NOT rejected
# Null hypothesis of non-stationarity of EMR series is NOT rejected
# Null hypothesis of non-stationarity of ENPH series is NOT rejected
# Null hypothesis of non-stationarity of EOG series is NOT rejected
# Null hypothesis of non-stationarity of EPAM series is NOT rejected
# Null hypothesis of non-stationarity of EQIX series is NOT rejected
# Null hypothesis of non-stationarity of EQR series is NOT rejected
# Null hypothesis of non-stationarity of ES series is NOT rejected
# Null hypothesis of non-stationarity of ESS series is NOT rejected
# Null hypothesis of non-stationarity of ETN series is NOT rejected
# Null hypothesis of non-stationarity of ETR series is NOT rejected
# Null hypothesis of non-stationarity of ETSY series is NOT rejected
# Null hypothesis of non-stationarity of EVRG series is NOT rejected
# Null hypothesis of non-stationarity of EW series is NOT rejected
# Null hypothesis of non-stationarity of EXC series is NOT rejected
# Null hypothesis of non-stationarity of EXPD series is NOT rejected
# Null hypothesis of non-stationarity of EXPE series is NOT rejected
# Null hypothesis of non-stationarity of EXR series is NOT rejected
# Null hypothesis of non-stationarity of F series is NOT rejected
# Null hypothesis of non-stationarity of FANG series is NOT rejected
# Null hypothesis of non-stationarity of FAST series is NOT rejected
# Null hypothesis of non-stationarity of FBHS series is NOT rejected
# Null hypothesis of non-stationarity of FCX series is NOT rejected
# Null hypothesis of non-stationarity of FDS series is NOT rejected
# Null hypothesis of non-stationarity of FDX series is NOT rejected
# Null hypothesis of non-stationarity of FE series is NOT rejected
# Null hypothesis of non-stationarity of FFIV series is NOT rejected
# Null hypothesis of non-stationarity of FIS series is NOT rejected
# Null hypothesis of non-stationarity of FISV series is NOT rejected
# Null hypothesis of non-stationarity of FITB series is NOT rejected
# Null hypothesis of non-stationarity of FLT series is NOT rejected
# Null hypothesis of non-stationarity of FMC series is NOT rejected
# Null hypothesis of non-stationarity of FRC series is NOT rejected
# Null hypothesis of non-stationarity of FRT series is NOT rejected
# Null hypothesis of non-stationarity of FTNT series is NOT rejected
# Null hypothesis of non-stationarity of FTV series is rejected
# Null hypothesis of non-stationarity of GD series is NOT rejected
# Null hypothesis of non-stationarity of GE series is NOT rejected
# Null hypothesis of non-stationarity of GILD series is rejected
# Null hypothesis of non-stationarity of GIS series is NOT rejected
# Null hypothesis of non-stationarity of GL series is rejected
# Null hypothesis of non-stationarity of GLW series is NOT rejected
# Null hypothesis of non-stationarity of GM series is NOT rejected
# Null hypothesis of non-stationarity of GNRC series is NOT rejected
# Null hypothesis of non-stationarity of GOOG series is NOT rejected
# Null hypothesis of non-stationarity of GOOGL series is NOT rejected
# Null hypothesis of non-stationarity of GPC series is NOT rejected
# Null hypothesis of non-stationarity of GPN series is NOT rejected
# Null hypothesis of non-stationarity of GRMN series is NOT rejected
# Null hypothesis of non-stationarity of GS series is NOT rejected
# Null hypothesis of non-stationarity of GWW series is NOT rejected
# Null hypothesis of non-stationarity of HAL series is NOT rejected
# Null hypothesis of non-stationarity of HAS series is rejected
# Null hypothesis of non-stationarity of HBAN series is NOT rejected
# Null hypothesis of non-stationarity of HCA series is NOT rejected
# Null hypothesis of non-stationarity of HD series is NOT rejected
# Null hypothesis of non-stationarity of HES series is NOT rejected
# Null hypothesis of non-stationarity of HIG series is NOT rejected
# Null hypothesis of non-stationarity of HII series is NOT rejected
# Null hypothesis of non-stationarity of HLT series is NOT rejected
# Null hypothesis of non-stationarity of HOLX series is NOT rejected
# Null hypothesis of non-stationarity of HON series is NOT rejected
# Null hypothesis of non-stationarity of HPE series is NOT rejected
# Null hypothesis of non-stationarity of HPQ series is NOT rejected
# Null hypothesis of non-stationarity of HRL series is NOT rejected
# Null hypothesis of non-stationarity of HSIC series is NOT rejected
# Null hypothesis of non-stationarity of HST series is NOT rejected
# Null hypothesis of non-stationarity of HSY series is NOT rejected
# Null hypothesis of non-stationarity of HUM series is NOT rejected
# Null hypothesis of non-stationarity of HWM series is NOT rejected
# Null hypothesis of non-stationarity of IBM series is rejected
# Null hypothesis of non-stationarity of ICE series is NOT rejected
# Null hypothesis of non-stationarity of IDXX series is NOT rejected
# Null hypothesis of non-stationarity of IEX series is NOT rejected
# Null hypothesis of non-stationarity of IFF series is rejected
# Null hypothesis of non-stationarity of ILMN series is NOT rejected
# Null hypothesis of non-stationarity of INCY series is rejected
# Null hypothesis of non-stationarity of INTC series is NOT rejected
# Null hypothesis of non-stationarity of INTU series is NOT rejected
# Null hypothesis of non-stationarity of INVH series is NOT rejected
# Null hypothesis of non-stationarity of IP series is NOT rejected
# Null hypothesis of non-stationarity of IPG series is NOT rejected
# Null hypothesis of non-stationarity of IQV series is NOT rejected
# Null hypothesis of non-stationarity of IR series is NOT rejected
# Null hypothesis of non-stationarity of IRM series is NOT rejected
# Null hypothesis of non-stationarity of ISRG series is NOT rejected
# Null hypothesis of non-stationarity of IT series is NOT rejected
# Null hypothesis of non-stationarity of ITW series is NOT rejected
# Null hypothesis of non-stationarity of IVZ series is NOT rejected
# Null hypothesis of non-stationarity of J series is NOT rejected
# Null hypothesis of non-stationarity of JBHT series is NOT rejected
# Null hypothesis of non-stationarity of JCI series is NOT rejected
# Null hypothesis of non-stationarity of JKHY series is NOT rejected
# Null hypothesis of non-stationarity of JNJ series is NOT rejected
# Null hypothesis of non-stationarity of JNPR series is NOT rejected
# Null hypothesis of non-stationarity of JPM series is NOT rejected
# Null hypothesis of non-stationarity of K series is NOT rejected
# Null hypothesis of non-stationarity of KDP series is NOT rejected
# Null hypothesis of non-stationarity of KEY series is NOT rejected
# Null hypothesis of non-stationarity of KEYS series is NOT rejected
# Null hypothesis of non-stationarity of KHC series is rejected
# Null hypothesis of non-stationarity of KIM series is NOT rejected
# Null hypothesis of non-stationarity of KLAC series is NOT rejected
# Null hypothesis of non-stationarity of KMB series is NOT rejected
# Null hypothesis of non-stationarity of KMI series is NOT rejected
# Null hypothesis of non-stationarity of KMX series is NOT rejected
# Null hypothesis of non-stationarity of KO series is NOT rejected
# Null hypothesis of non-stationarity of KR series is NOT rejected
# Null hypothesis of non-stationarity of L series is NOT rejected
# Null hypothesis of non-stationarity of LDOS series is NOT rejected
# Null hypothesis of non-stationarity of LEN series is NOT rejected
# Null hypothesis of non-stationarity of LH series is NOT rejected
# Null hypothesis of non-stationarity of LHX series is NOT rejected
# Null hypothesis of non-stationarity of LIN series is NOT rejected
# Null hypothesis of non-stationarity of LKQ series is NOT rejected
# Null hypothesis of non-stationarity of LLY series is NOT rejected
# Null hypothesis of non-stationarity of LMT series is NOT rejected
# Null hypothesis of non-stationarity of LNC series is NOT rejected
# Null hypothesis of non-stationarity of LNT series is NOT rejected
# Null hypothesis of non-stationarity of LOW series is NOT rejected
# Null hypothesis of non-stationarity of LRCX series is NOT rejected
# Null hypothesis of non-stationarity of LUMN series is NOT rejected
# Null hypothesis of non-stationarity of LUV series is NOT rejected
# Null hypothesis of non-stationarity of LVS series is NOT rejected
# Null hypothesis of non-stationarity of LW series is rejected
# Null hypothesis of non-stationarity of LYB series is NOT rejected
# Null hypothesis of non-stationarity of LYV series is NOT rejected
# Null hypothesis of non-stationarity of MA series is NOT rejected
# Null hypothesis of non-stationarity of MAA series is NOT rejected
# Null hypothesis of non-stationarity of MAR series is NOT rejected
# Null hypothesis of non-stationarity of MAS series is NOT rejected
# Null hypothesis of non-stationarity of MCD series is NOT rejected
# Null hypothesis of non-stationarity of MCHP series is NOT rejected
# Null hypothesis of non-stationarity of MCK series is NOT rejected
# Null hypothesis of non-stationarity of MCO series is NOT rejected
# Null hypothesis of non-stationarity of MDLZ series is NOT rejected
# Null hypothesis of non-stationarity of MDT series is NOT rejected
# Null hypothesis of non-stationarity of MET series is NOT rejected
# Null hypothesis of non-stationarity of META series is NOT rejected
# Null hypothesis of non-stationarity of MGM series is NOT rejected
# Null hypothesis of non-stationarity of MHK series is NOT rejected
# Null hypothesis of non-stationarity of MKC series is NOT rejected
# Null hypothesis of non-stationarity of MKTX series is NOT rejected
# Null hypothesis of non-stationarity of MLM series is NOT rejected
# Null hypothesis of non-stationarity of MMC series is NOT rejected
# Null hypothesis of non-stationarity of MMM series is NOT rejected
# Null hypothesis of non-stationarity of MNST series is NOT rejected
# Null hypothesis of non-stationarity of MO series is rejected
# Null hypothesis of non-stationarity of MOH series is NOT rejected
# Null hypothesis of non-stationarity of MOS series is NOT rejected
# Null hypothesis of non-stationarity of MPC series is NOT rejected
# Null hypothesis of non-stationarity of MPWR series is NOT rejected
# Null hypothesis of non-stationarity of MRK series is NOT rejected
# Null hypothesis of non-stationarity of MRO series is NOT rejected
# Null hypothesis of non-stationarity of MS series is NOT rejected
# Null hypothesis of non-stationarity of MSCI series is NOT rejected
# Null hypothesis of non-stationarity of MSFT series is NOT rejected
# Null hypothesis of non-stationarity of MSI series is NOT rejected
# Null hypothesis of non-stationarity of MTB series is NOT rejected
# Null hypothesis of non-stationarity of MTCH series is NOT rejected
# Null hypothesis of non-stationarity of MTD series is NOT rejected
# Null hypothesis of non-stationarity of MU series is NOT rejected
# Null hypothesis of non-stationarity of NCLH series is NOT rejected
# Null hypothesis of non-stationarity of NDAQ series is NOT rejected
# Null hypothesis of non-stationarity of NDSN series is NOT rejected
# Null hypothesis of non-stationarity of NEE series is NOT rejected
# Null hypothesis of non-stationarity of NEM series is NOT rejected
# Null hypothesis of non-stationarity of NFLX series is NOT rejected
# Null hypothesis of non-stationarity of NI series is NOT rejected
# Null hypothesis of non-stationarity of NKE series is NOT rejected
# Null hypothesis of non-stationarity of NLOK series is rejected
# Null hypothesis of non-stationarity of NLSN series is NOT rejected
# Null hypothesis of non-stationarity of NOC series is NOT rejected
# Null hypothesis of non-stationarity of NOW series is NOT rejected
# Null hypothesis of non-stationarity of NRG series is rejected
# Null hypothesis of non-stationarity of NSC series is NOT rejected
# Null hypothesis of non-stationarity of NTAP series is NOT rejected
# Null hypothesis of non-stationarity of NTRS series is NOT rejected
# Null hypothesis of non-stationarity of NUE series is NOT rejected
# Null hypothesis of non-stationarity of NVDA series is NOT rejected
# Null hypothesis of non-stationarity of NVR series is NOT rejected
# Null hypothesis of non-stationarity of NWL series is NOT rejected
# Null hypothesis of non-stationarity of NWS series is NOT rejected
# Null hypothesis of non-stationarity of NWSA series is NOT rejected
# Null hypothesis of non-stationarity of NXPI series is NOT rejected
# Null hypothesis of non-stationarity of O series is NOT rejected
# Null hypothesis of non-stationarity of ODFL series is NOT rejected
# Null hypothesis of non-stationarity of OKE series is NOT rejected
# Null hypothesis of non-stationarity of OMC series is NOT rejected
# Null hypothesis of non-stationarity of ON series is NOT rejected
# Null hypothesis of non-stationarity of ORCL series is NOT rejected
# Null hypothesis of non-stationarity of ORLY series is NOT rejected
# Null hypothesis of non-stationarity of OXY series is NOT rejected
# Null hypothesis of non-stationarity of PARA series is NOT rejected
# Null hypothesis of non-stationarity of PAYC series is NOT rejected
# Null hypothesis of non-stationarity of PAYX series is NOT rejected
# Null hypothesis of non-stationarity of PCAR series is NOT rejected
# Null hypothesis of non-stationarity of PEAK series is NOT rejected
# Null hypothesis of non-stationarity of PEG series is NOT rejected
# Null hypothesis of non-stationarity of PEP series is NOT rejected
# Null hypothesis of non-stationarity of PFE series is NOT rejected
# Null hypothesis of non-stationarity of PFG series is NOT rejected
# Null hypothesis of non-stationarity of PG series is NOT rejected
# Null hypothesis of non-stationarity of PGR series is NOT rejected
# Null hypothesis of non-stationarity of PH series is NOT rejected
# Null hypothesis of non-stationarity of PHM series is NOT rejected
# Null hypothesis of non-stationarity of PKG series is NOT rejected
# Null hypothesis of non-stationarity of PKI series is NOT rejected
# Null hypothesis of non-stationarity of PLD series is NOT rejected
# Null hypothesis of non-stationarity of PM series is NOT rejected
# Null hypothesis of non-stationarity of PNC series is NOT rejected
# Null hypothesis of non-stationarity of PNR series is NOT rejected
# Null hypothesis of non-stationarity of PNW series is NOT rejected
# Null hypothesis of non-stationarity of POOL series is NOT rejected
# Null hypothesis of non-stationarity of PPG series is NOT rejected
# Null hypothesis of non-stationarity of PPL series is rejected
# Null hypothesis of non-stationarity of PRU series is NOT rejected
# Null hypothesis of non-stationarity of PSA series is NOT rejected
# Null hypothesis of non-stationarity of PSX series is NOT rejected
# Null hypothesis of non-stationarity of PTC series is NOT rejected
# Null hypothesis of non-stationarity of PWR series is NOT rejected
# Null hypothesis of non-stationarity of PXD series is NOT rejected
# Null hypothesis of non-stationarity of PYPL series is NOT rejected
# Null hypothesis of non-stationarity of QCOM series is NOT rejected
# Null hypothesis of non-stationarity of QRVO series is NOT rejected
# Null hypothesis of non-stationarity of RCL series is NOT rejected
# Null hypothesis of non-stationarity of RE series is NOT rejected
# Null hypothesis of non-stationarity of REG series is NOT rejected
# Null hypothesis of non-stationarity of REGN series is NOT rejected
# Null hypothesis of non-stationarity of RF series is NOT rejected
# Null hypothesis of non-stationarity of RHI series is NOT rejected
# Null hypothesis of non-stationarity of RJF series is NOT rejected
# Null hypothesis of non-stationarity of RL series is NOT rejected
# Null hypothesis of non-stationarity of RMD series is NOT rejected
# Null hypothesis of non-stationarity of ROK series is NOT rejected
# Null hypothesis of non-stationarity of ROL series is NOT rejected
# Null hypothesis of non-stationarity of ROP series is NOT rejected
# Null hypothesis of non-stationarity of ROST series is NOT rejected
# Null hypothesis of non-stationarity of RSG series is NOT rejected
# Null hypothesis of non-stationarity of RTX series is NOT rejected
# Null hypothesis of non-stationarity of SBAC series is NOT rejected
# Null hypothesis of non-stationarity of SBNY series is NOT rejected
# Null hypothesis of non-stationarity of SBUX series is NOT rejected
# Null hypothesis of non-stationarity of SCHW series is NOT rejected
# Null hypothesis of non-stationarity of SEDG series is NOT rejected
# Null hypothesis of non-stationarity of SEE series is NOT rejected
# Null hypothesis of non-stationarity of SHW series is NOT rejected
# Null hypothesis of non-stationarity of SIVB series is NOT rejected
# Null hypothesis of non-stationarity of SJM series is NOT rejected
# Null hypothesis of non-stationarity of SLB series is NOT rejected
# Null hypothesis of non-stationarity of SNA series is NOT rejected
# Null hypothesis of non-stationarity of SNPS series is NOT rejected
# Null hypothesis of non-stationarity of SO series is NOT rejected
# Null hypothesis of non-stationarity of SPG series is NOT rejected
# Null hypothesis of non-stationarity of SPGI series is NOT rejected
# Null hypothesis of non-stationarity of SRE series is NOT rejected
# Null hypothesis of non-stationarity of STE series is NOT rejected
# Null hypothesis of non-stationarity of STT series is NOT rejected
# Null hypothesis of non-stationarity of STX series is NOT rejected
# Null hypothesis of non-stationarity of STZ series is NOT rejected
# Null hypothesis of non-stationarity of SWK series is NOT rejected
# Null hypothesis of non-stationarity of SWKS series is NOT rejected
# Null hypothesis of non-stationarity of SYF series is NOT rejected
# Null hypothesis of non-stationarity of SYK series is NOT rejected
# Null hypothesis of non-stationarity of SYY series is NOT rejected
# Null hypothesis of non-stationarity of T series is NOT rejected
# Null hypothesis of non-stationarity of TAP series is NOT rejected
# Null hypothesis of non-stationarity of TDG series is NOT rejected
# Null hypothesis of non-stationarity of TDY series is NOT rejected
# Null hypothesis of non-stationarity of TECH series is NOT rejected
# Null hypothesis of non-stationarity of TEL series is NOT rejected
# Null hypothesis of non-stationarity of TER series is NOT rejected
# Null hypothesis of non-stationarity of TFC series is NOT rejected
# Null hypothesis of non-stationarity of TFX series is NOT rejected
# Null hypothesis of non-stationarity of TGT series is NOT rejected
# Null hypothesis of non-stationarity of TJX series is NOT rejected
# Null hypothesis of non-stationarity of TMO series is NOT rejected
# Null hypothesis of non-stationarity of TMUS series is NOT rejected
# Null hypothesis of non-stationarity of TPR series is NOT rejected
# Null hypothesis of non-stationarity of TRMB series is NOT rejected
# Null hypothesis of non-stationarity of TROW series is NOT rejected
# Null hypothesis of non-stationarity of TRV series is NOT rejected
# Null hypothesis of non-stationarity of TSCO series is NOT rejected
# Null hypothesis of non-stationarity of TSLA series is NOT rejected
# Null hypothesis of non-stationarity of TSN series is NOT rejected
# Null hypothesis of non-stationarity of TT series is NOT rejected
# Null hypothesis of non-stationarity of TTWO series is NOT rejected
# Null hypothesis of non-stationarity of TWTR series is NOT rejected
# Null hypothesis of non-stationarity of TXN series is NOT rejected
# Null hypothesis of non-stationarity of TXT series is NOT rejected
# Null hypothesis of non-stationarity of TYL series is NOT rejected
# Null hypothesis of non-stationarity of UAL series is NOT rejected
# Null hypothesis of non-stationarity of UDR series is NOT rejected
# Null hypothesis of non-stationarity of UHS series is NOT rejected
# Null hypothesis of non-stationarity of ULTA series is NOT rejected
# Null hypothesis of non-stationarity of UNH series is NOT rejected
# Null hypothesis of non-stationarity of UNP series is NOT rejected
# Null hypothesis of non-stationarity of UPS series is NOT rejected
# Null hypothesis of non-stationarity of URI series is NOT rejected
# Null hypothesis of non-stationarity of USB series is NOT rejected
# Null hypothesis of non-stationarity of V series is NOT rejected
# Null hypothesis of non-stationarity of VFC series is NOT rejected
# Null hypothesis of non-stationarity of VICI series is NOT rejected
# Null hypothesis of non-stationarity of VLO series is NOT rejected
# Null hypothesis of non-stationarity of VMC series is NOT rejected
# Null hypothesis of non-stationarity of VNO series is NOT rejected
# Null hypothesis of non-stationarity of VRSK series is NOT rejected
# Null hypothesis of non-stationarity of VRSN series is NOT rejected
# Null hypothesis of non-stationarity of VRTX series is NOT rejected
# Null hypothesis of non-stationarity of VTR series is NOT rejected
# Null hypothesis of non-stationarity of VTRS series is NOT rejected
# Null hypothesis of non-stationarity of VZ series is NOT rejected
# Null hypothesis of non-stationarity of WAB series is NOT rejected
# Null hypothesis of non-stationarity of WAT series is NOT rejected
# Null hypothesis of non-stationarity of WBA series is NOT rejected
# Null hypothesis of non-stationarity of WBD series is NOT rejected
# Null hypothesis of non-stationarity of WDC series is NOT rejected
# Null hypothesis of non-stationarity of WEC series is NOT rejected
# Null hypothesis of non-stationarity of WELL series is NOT rejected
# Null hypothesis of non-stationarity of WFC series is NOT rejected
# Null hypothesis of non-stationarity of WHR series is NOT rejected
# Null hypothesis of non-stationarity of WM series is NOT rejected
# Null hypothesis of non-stationarity of WMB series is NOT rejected
# Null hypothesis of non-stationarity of WMT series is NOT rejected
# Null hypothesis of non-stationarity of WRB series is NOT rejected
# Null hypothesis of non-stationarity of WRK series is NOT rejected
# Null hypothesis of non-stationarity of WST series is NOT rejected
# Null hypothesis of non-stationarity of WTW series is NOT rejected
# Null hypothesis of non-stationarity of WY series is NOT rejected
# Null hypothesis of non-stationarity of WYNN series is NOT rejected
# Null hypothesis of non-stationarity of XEL series is NOT rejected
# Null hypothesis of non-stationarity of XOM series is NOT rejected
# Null hypothesis of non-stationarity of XRAY series is NOT rejected
# Null hypothesis of non-stationarity of XYL series is NOT rejected
# Null hypothesis of non-stationarity of YUM series is NOT rejected
# Null hypothesis of non-stationarity of ZBH series is NOT rejected
# Null hypothesis of non-stationarity of ZBRA series is NOT rejected
# Null hypothesis of non-stationarity of ZION series is NOT rejected
# Null hypothesis of non-stationarity of ZTS series is NOT rejected

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1174 entries, 02-01-2018 to 30-08-2022
# Columns: 491 entries, A to ZTS
# dtypes: float64(491)
# memory usage: 4.4+ MB

# %%
def transform1(column):
    """
    Log first difference multiplied by 100 transformation (i.e. approximate percent change)
    """
    column = np.log(column).diff() * 100       
    return column

# %%
data1 = data.apply(transform1, axis=0)

# %%
def transform2(column):
    """
    First difference multiplied by 100 transformation
    """
    column = column.diff() * 100       
    return column

# %%
def remove_outliers(df):
    """
    Remove outliers (setting their value to missing), defined as observations that are more than 5X 
    the interquartile range from the series mean
    """    
    # Compute the mean and interquartile range
    mean = df.mean()
    iqr = df.quantile([0.25, 0.75]).diff().T.iloc[:, 1]
    
    # Replace entries that are more than 10 times the IQR
    # away from the mean with NaN (denotes a missing entry)
    mask = np.abs(df) > mean + 5 * iqr
    treated = df.copy()
    treated[mask] = np.nan

    return treated

# %%
data_station = remove_outliers(data)

# %%
data_station.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1174 entries, 02-01-2018 to 30-08-2022
# Columns: 491 entries, A to ZTS
# dtypes: float64(491)
# memory usage: 4.4+ MB

# %%
endog_dj = data_station.reset_index(drop=True)

# %%
import statsmodels.api as sm
factors = ['factor01', 'factor02', 'factor03']
factor_orders = 8
model = sm.tsa.DynamicFactorMQ(endog_dj, factors=factors, factor_orders=factor_orders, standardize=True)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                          Model Specification: Dynamic Factor Model
# ===========================================================================================
# Model:                Dynamic Factor Model   # of observed variables:                   491
#                    + 3 factors in 3 blocks   # of factor blocks:                          3
#                      + AR(1) idiosyncratic   Idiosyncratic disturbances:              AR(1)
# Sample:                                  0   Standardize variables:                    True
#                                     - 1174
#      Observed variables / factor loadings
# ==============================================
# Dep. variable   factor01   factor02   factor03
# ----------------------------------------------
#             A      X          X          X
#           AAL      X          X          X
#           AAP      X          X          X
#          AAPL      X          X          X
#          ABBV      X          X          X
#           ABC      X          X          X
#          ABMD      X          X          X
#           ABT      X          X          X
#           ACN      X          X          X
#          ADBE      X          X          X
#           ADI      X          X          X
#           ADM      X          X          X
#           ADP      X          X          X
#          ADSK      X          X          X
#           AEE      X          X          X
#           AEP      X          X          X
#           AES      X          X          X
#           AFL      X          X          X
#           AIG      X          X          X
#           AIZ      X          X          X
#           AJG      X          X          X
#          AKAM      X          X          X
#           ALB      X          X          X
#          ALGN      X          X          X
#           ALK      X          X          X
#           ALL      X          X          X
#          ALLE      X          X          X
#          AMAT      X          X          X
#          AMCR      X          X          X
#           AMD      X          X          X
#           AME      X          X          X
#          AMGN      X          X          X
#           AMP      X          X          X
#           AMT      X          X          X
#          AMZN      X          X          X
#          ANET      X          X          X
#          ANSS      X          X          X
#           AON      X          X          X
#           AOS      X          X          X
#           APA      X          X          X
#           APD      X          X          X
#           APH      X          X          X
#          APTV      X          X          X
#           ARE      X          X          X
#           ATO      X          X          X
#          ATVI      X          X          X
#           AVB      X          X          X
#          AVGO      X          X          X
#           AVY      X          X          X
#           AWK      X          X          X
#           AXP      X          X          X
#           AZO      X          X          X
#            BA      X          X          X
#           BAC      X          X          X
#          BALL      X          X          X
#           BAX      X          X          X
#          BBWI      X          X          X
#           BBY      X          X          X
#           BDX      X          X          X
#           BEN      X          X          X
#          BIIB      X          X          X
#           BIO      X          X          X
#            BK      X          X          X
#          BKNG      X          X          X
#           BKR      X          X          X
#           BLK      X          X          X
#           BMY      X          X          X
#            BR      X          X          X
#           BRO      X          X          X
#           BSX      X          X          X
#           BWA      X          X          X
#           BXP      X          X          X
#             C      X          X          X
#           CAG      X          X          X
#           CAH      X          X          X
#           CAT      X          X          X
#            CB      X          X          X
#          CBOE      X          X          X
#          CBRE      X          X          X
#           CCI      X          X          X
#           CCL      X          X          X
#          CDNS      X          X          X
#           CDW      X          X          X
#            CE      X          X          X
#            CF      X          X          X
#           CFG      X          X          X
#           CHD      X          X          X
#          CHRW      X          X          X
#          CHTR      X          X          X
#            CI      X          X          X
#          CINF      X          X          X
#            CL      X          X          X
#           CLX      X          X          X
#           CMA      X          X          X
#         CMCSA      X          X          X
#           CME      X          X          X
#           CMG      X          X          X
#           CMI      X          X          X
#           CMS      X          X          X
#           CNC      X          X          X
#           CNP      X          X          X
#           COF      X          X          X
#           COO      X          X          X
#           COP      X          X          X
#          COST      X          X          X
#           CPB      X          X          X
#          CPRT      X          X          X
#           CPT      X          X          X
#           CRL      X          X          X
#           CRM      X          X          X
#          CSCO      X          X          X
#          CSGP      X          X          X
#           CSX      X          X          X
#          CTAS      X          X          X
#          CTLT      X          X          X
#          CTRA      X          X          X
#          CTSH      X          X          X
#          CTXS      X          X          X
#           CVS      X          X          X
#           CVX      X          X          X
#           CZR      X          X          X
#             D      X          X          X
#           DAL      X          X          X
#            DD      X          X          X
#            DE      X          X          X
#           DFS      X          X          X
#            DG      X          X          X
#           DGX      X          X          X
#           DHI      X          X          X
#           DHR      X          X          X
#           DIS      X          X          X
#          DISH      X          X          X
#           DLR      X          X          X
#          DLTR      X          X          X
#           DOV      X          X          X
#           DPZ      X          X          X
#           DRE      X          X          X
#           DRI      X          X          X
#           DTE      X          X          X
#           DUK      X          X          X
#           DVA      X          X          X
#           DVN      X          X          X
#           DXC      X          X          X
#          DXCM      X          X          X
#            EA      X          X          X
#          EBAY      X          X          X
#           ECL      X          X          X
#            ED      X          X          X
#           EFX      X          X          X
#           EIX      X          X          X
#            EL      X          X          X
#           ELV      X          X          X
#           EMN      X          X          X
#           EMR      X          X          X
#          ENPH      X          X          X
#           EOG      X          X          X
#          EPAM      X          X          X
#          EQIX      X          X          X
#           EQR      X          X          X
#            ES      X          X          X
#           ESS      X          X          X
#           ETN      X          X          X
#           ETR      X          X          X
#          ETSY      X          X          X
#          EVRG      X          X          X
#            EW      X          X          X
#           EXC      X          X          X
#          EXPD      X          X          X
#          EXPE      X          X          X
#           EXR      X          X          X
#             F      X          X          X
#          FANG      X          X          X
#          FAST      X          X          X
#          FBHS      X          X          X
#           FCX      X          X          X
#           FDS      X          X          X
#           FDX      X          X          X
#            FE      X          X          X
#          FFIV      X          X          X
#           FIS      X          X          X
#          FISV      X          X          X
#          FITB      X          X          X
#           FLT      X          X          X
#           FMC      X          X          X
#           FRC      X          X          X
#           FRT      X          X          X
#          FTNT      X          X          X
#           FTV      X          X          X
#            GD      X          X          X
#            GE      X          X          X
#          GILD      X          X          X
#           GIS      X          X          X
#            GL      X          X          X
#           GLW      X          X          X
#            GM      X          X          X
#          GNRC      X          X          X
#          GOOG      X          X          X
#         GOOGL      X          X          X
#           GPC      X          X          X
#           GPN      X          X          X
#          GRMN      X          X          X
#            GS      X          X          X
#           GWW      X          X          X
#           HAL      X          X          X
#           HAS      X          X          X
#          HBAN      X          X          X
#           HCA      X          X          X
#            HD      X          X          X
#           HES      X          X          X
#           HIG      X          X          X
#           HII      X          X          X
#           HLT      X          X          X
#          HOLX      X          X          X
#           HON      X          X          X
#           HPE      X          X          X
#           HPQ      X          X          X
#           HRL      X          X          X
#          HSIC      X          X          X
#           HST      X          X          X
#           HSY      X          X          X
#           HUM      X          X          X
#           HWM      X          X          X
#           IBM      X          X          X
#           ICE      X          X          X
#          IDXX      X          X          X
#           IEX      X          X          X
#           IFF      X          X          X
#          ILMN      X          X          X
#          INCY      X          X          X
#          INTC      X          X          X
#          INTU      X          X          X
#          INVH      X          X          X
#            IP      X          X          X
#           IPG      X          X          X
#           IQV      X          X          X
#            IR      X          X          X
#           IRM      X          X          X
#          ISRG      X          X          X
#            IT      X          X          X
#           ITW      X          X          X
#           IVZ      X          X          X
#             J      X          X          X
#          JBHT      X          X          X
#           JCI      X          X          X
#          JKHY      X          X          X
#           JNJ      X          X          X
#          JNPR      X          X          X
#           JPM      X          X          X
#             K      X          X          X
#           KDP      X          X          X
#           KEY      X          X          X
#          KEYS      X          X          X
#           KHC      X          X          X
#           KIM      X          X          X
#          KLAC      X          X          X
#           KMB      X          X          X
#           KMI      X          X          X
#           KMX      X          X          X
#            KO      X          X          X
#            KR      X          X          X
#             L      X          X          X
#          LDOS      X          X          X
#           LEN      X          X          X
#            LH      X          X          X
#           LHX      X          X          X
#           LIN      X          X          X
#           LKQ      X          X          X
#           LLY      X          X          X
#           LMT      X          X          X
#           LNC      X          X          X
#           LNT      X          X          X
#           LOW      X          X          X
#          LRCX      X          X          X
#          LUMN      X          X          X
#           LUV      X          X          X
#           LVS      X          X          X
#            LW      X          X          X
#           LYB      X          X          X
#           LYV      X          X          X
#            MA      X          X          X
#           MAA      X          X          X
#           MAR      X          X          X
#           MAS      X          X          X
#           MCD      X          X          X
#          MCHP      X          X          X
#           MCK      X          X          X
#           MCO      X          X          X
#          MDLZ      X          X          X
#           MDT      X          X          X
#           MET      X          X          X
#          META      X          X          X
#           MGM      X          X          X
#           MHK      X          X          X
#           MKC      X          X          X
#          MKTX      X          X          X
#           MLM      X          X          X
#           MMC      X          X          X
#           MMM      X          X          X
#          MNST      X          X          X
#            MO      X          X          X
#           MOH      X          X          X
#           MOS      X          X          X
#           MPC      X          X          X
#          MPWR      X          X          X
#           MRK      X          X          X
#           MRO      X          X          X
#            MS      X          X          X
#          MSCI      X          X          X
#          MSFT      X          X          X
#           MSI      X          X          X
#           MTB      X          X          X
#          MTCH      X          X          X
#           MTD      X          X          X
#            MU      X          X          X
#          NCLH      X          X          X
#          NDAQ      X          X          X
#          NDSN      X          X          X
#           NEE      X          X          X
#           NEM      X          X          X
#          NFLX      X          X          X
#            NI      X          X          X
#           NKE      X          X          X
#          NLOK      X          X          X
#          NLSN      X          X          X
#           NOC      X          X          X
#           NOW      X          X          X
#           NRG      X          X          X
#           NSC      X          X          X
#          NTAP      X          X          X
#          NTRS      X          X          X
#           NUE      X          X          X
#          NVDA      X          X          X
#           NVR      X          X          X
#           NWL      X          X          X
#           NWS      X          X          X
#          NWSA      X          X          X
#          NXPI      X          X          X
#             O      X          X          X
#          ODFL      X          X          X
#           OKE      X          X          X
#           OMC      X          X          X
#            ON      X          X          X
#          ORCL      X          X          X
#          ORLY      X          X          X
#           OXY      X          X          X
#          PARA      X          X          X
#          PAYC      X          X          X
#          PAYX      X          X          X
#          PCAR      X          X          X
#          PEAK      X          X          X
#           PEG      X          X          X
#           PEP      X          X          X
#           PFE      X          X          X
#           PFG      X          X          X
#            PG      X          X          X
#           PGR      X          X          X
#            PH      X          X          X
#           PHM      X          X          X
#           PKG      X          X          X
#           PKI      X          X          X
#           PLD      X          X          X
#            PM      X          X          X
#           PNC      X          X          X
#           PNR      X          X          X
#           PNW      X          X          X
#          POOL      X          X          X
#           PPG      X          X          X
#           PPL      X          X          X
#           PRU      X          X          X
#           PSA      X          X          X
#           PSX      X          X          X
#           PTC      X          X          X
#           PWR      X          X          X
#           PXD      X          X          X
#          PYPL      X          X          X
#          QCOM      X          X          X
#          QRVO      X          X          X
#           RCL      X          X          X
#            RE      X          X          X
#           REG      X          X          X
#          REGN      X          X          X
#            RF      X          X          X
#           RHI      X          X          X
#           RJF      X          X          X
#            RL      X          X          X
#           RMD      X          X          X
#           ROK      X          X          X
#           ROL      X          X          X
#           ROP      X          X          X
#          ROST      X          X          X
#           RSG      X          X          X
#           RTX      X          X          X
#          SBAC      X          X          X
#          SBNY      X          X          X
#          SBUX      X          X          X
#          SCHW      X          X          X
#          SEDG      X          X          X
#           SEE      X          X          X
#           SHW      X          X          X
#          SIVB      X          X          X
#           SJM      X          X          X
#           SLB      X          X          X
#           SNA      X          X          X
#          SNPS      X          X          X
#            SO      X          X          X
#           SPG      X          X          X
#          SPGI      X          X          X
#           SRE      X          X          X
#           STE      X          X          X
#           STT      X          X          X
#           STX      X          X          X
#           STZ      X          X          X
#           SWK      X          X          X
#          SWKS      X          X          X
#           SYF      X          X          X
#           SYK      X          X          X
#           SYY      X          X          X
#             T      X          X          X
#           TAP      X          X          X
#           TDG      X          X          X
#           TDY      X          X          X
#          TECH      X          X          X
#           TEL      X          X          X
#           TER      X          X          X
#           TFC      X          X          X
#           TFX      X          X          X
#           TGT      X          X          X
#           TJX      X          X          X
#           TMO      X          X          X
#          TMUS      X          X          X
#           TPR      X          X          X
#          TRMB      X          X          X
#          TROW      X          X          X
#           TRV      X          X          X
#          TSCO      X          X          X
#          TSLA      X          X          X
#           TSN      X          X          X
#            TT      X          X          X
#          TTWO      X          X          X
#          TWTR      X          X          X
#           TXN      X          X          X
#           TXT      X          X          X
#           TYL      X          X          X
#           UAL      X          X          X
#           UDR      X          X          X
#           UHS      X          X          X
#          ULTA      X          X          X
#           UNH      X          X          X
#           UNP      X          X          X
#           UPS      X          X          X
#           URI      X          X          X
#           USB      X          X          X
#             V      X          X          X
#           VFC      X          X          X
#          VICI      X          X          X
#           VLO      X          X          X
#           VMC      X          X          X
#           VNO      X          X          X
#          VRSK      X          X          X
#          VRSN      X          X          X
#          VRTX      X          X          X
#           VTR      X          X          X
#          VTRS      X          X          X
#            VZ      X          X          X
#           WAB      X          X          X
#           WAT      X          X          X
#           WBA      X          X          X
#           WBD      X          X          X
#           WDC      X          X          X
#           WEC      X          X          X
#          WELL      X          X          X
#           WFC      X          X          X
#           WHR      X          X          X
#            WM      X          X          X
#           WMB      X          X          X
#           WMT      X          X          X
#           WRB      X          X          X
#           WRK      X          X          X
#           WST      X          X          X
#           WTW      X          X          X
#            WY      X          X          X
#          WYNN      X          X          X
#           XEL      X          X          X
#           XOM      X          X          X
#          XRAY      X          X          X
#           XYL      X          X          X
#           YUM      X          X          X
#           ZBH      X          X          X
#          ZBRA      X          X          X
#          ZION      X          X          X
#           ZTS      X          X          X
#     Factor blocks:
# =====================
#      block      order
# ---------------------
#   factor01          8
#   factor02          8
#   factor03          8
# =====================
# """

# %%
results = model.fit(disp=10)
# Out:
# C:\Users\HP WORLD ANAND\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File statsmodels\tsa\statespace\_kalman_smoother.pyx:1014, in statsmodels.tsa.statespace._kalman_smoother.dKalmanSmoother.allocate_arrays()
#
# MemoryError: Unable to allocate 2.32 GiB for an array with shape (515, 515, 1175) and data type float64

# %%
results.summary(display_diagnostics=True)

# %%
results.factors.smoothed.head()

# %%
dj_smoothed = results.factors.smoothed

# %%
dj_smoothed

# %%
import seaborn as sns
import matplotlib.pyplot as plt
with sns.color_palette('deep'):
    fig, ax = plt.subplots(figsize=(16, 8))
    dj_smoothed.plot(ax=ax)
    
    plt.title('Estimated Three Factors', fontsize=16);

# %%
import platform
print(platform.architecture())
# Out:
# ('64bit', 'WindowsPE')
